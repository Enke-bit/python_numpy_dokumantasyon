# %%
# Burda görsel açmak için farklı bir kütüpane kullandım ama o kafanızı karıştırmasın.

import numpy as np
from PIL import Image

# %%
# Burda bu kavramların farkını göreçeğiz.

Image.open("./scalar-vector-matrix-tensor.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1008x357>

# %% [raw]
# # Yazılırken farklarını nasıl görürüz peki;

# %%
scalar = np.array(1)

# %%
vector = np.array([1,2])

# %%
matrix = np.array([[1,2],[3,4]])

# %%
tensor = np.array([[[1,2],[3,2],[1,7],[5,4]]])

# %%
# ekran çıktılarına bakalım;

print("noktasal veri:\n", scalar)
print("vevtörel veri:\n", vector)
print("matriks veri:\n", matrix)
print("tensor veri:\n", tensor)
# Out:
# noktasal veri:
#  1
# vevtörel veri:
#  [1 2]
# matriks veri:
#  [[1 2]
#  [3 4]]
# tensor veri:
#  [[[1 2]
#   [3 2]
#   [1 7]
#   [5 4]]]
